# %% [markdown]
# # 自動投稿実行例

# %%
# キャプション生成

from utils.caption_agent import generate_instagram_caption
import json

user_input = {
    "business_type": "Private tour company",
    "title": "Welcome to the Stunning Autumn Colors of Shiga",
    "direction": "Please create content that highlights the beauty of Shiga’s autumn foliage and encourages visitors to come."
}
templates_json = json.load(open("utils/template_example.json", "r", encoding="utf-8"))

result = generate_instagram_caption(user_input,templates_json)

print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 13
#       6 user_input = {
#       7     "business_type": "Private tour company",
#       8     "title": "Welcome to the Stunning Autumn Colors of Shiga",
#       9     "direction": "Please create content that highlights the beauty of Shiga’s autumn foliage and encourages visitors to come."
#      10 }
#      11 templates_json = json.load(open("utils/template_example.json", "r", encoding="utf-8"))
# ---> 13 result = generate_instagram_caption(user_input,templates_json)
#      15 print(json.dumps(result, ensure_ascii=False, indent=2))
#
# File c:\Users\AVRJ0006\YamatoDX\YAMATO_learning_practice\instagram_auto_post_system\project_git\instagram-auto-post-system\utils\caption_agent.py:396, in generate_instagram_caption(user_input, templates_json, model)
#     383 """
#     384 Instagram 自動投稿生成のフルパイプライン。
#     385 - Template Selector
#    (...)    390 最終キャプションと中間結果すべて返す。
#     391 """
#     393 # ----------------------------------------
#     394 # 1. Template Selector（テンプレ選択）
#     395 # ----------------------------------------
# --> 396 selector_output = run_template_selector(
#     397     user_input=user_input,
#     398     templates_json=templates_json,
#     399     model=model
#     400 )
#     401 selected_template = selector_output["selected_template"]
#     403 # ----------------------------------------
#     404 # 2. Caption Planner（構造作成 & RAGクエリ生成）
#     405 # ----------------------------------------
#
# File c:\Users\AVRJ0006\YamatoDX\YAMATO_learning_practice\instagram_auto_post_system\project_git\instagram-auto-post-system\utils\caption_agent.py:103, in run_template_selector(user_input, templates_json, model)
#      98 system_prompt = template_selector_prompt.format(
#      99     TEMPLATES=json.dumps(extracted_templates, ensure_ascii=False, indent=2)
#     100 )
#     102 # history= に system prompt を最初のメッセージとして渡す
# --> 103 return run_gpt_json(
#     104     prompt=json.dumps(user_input, ensure_ascii=False),
#     105     history=[{"role": "system", "content": system_prompt}],
#     106     model=model,
#     107     max_completion_tokens=1024,
#     108 )
#
# File c:\Users\AVRJ0006\YamatoDX\YAMATO_learning_practice\instagram_auto_post_system\project_git\instagram-auto-post-system\utils\llm.py:116, in run_gpt_json(prompt, history, model, max_completion_tokens)
#     107 def run_gpt_json(
#     108     prompt: str,
#     109     history: Optional[Sequence[ChatMessage]] = None,
#    (...)    112     max_completion_tokens: Optional[int] = None,
#     113 ):
#     114     messages = build_messages(prompt, history)
# --> 116     response = client.responses.create(
#     117         model=model,
#     118         input=[
#     119             {
#     120                 "role": msg["role"],
#     121                 "content": [{"type": "text", "text": msg["content"]}],
#     122             }
#     123             for msg in messages
#     124         ],
#     125         max_output_tokens=max_completion_tokens,
#     126     )
#     128     content = response.output[0].content[0].text
#     129     return json.loads(content)
#
# File c:\Users\AVRJ0006\anaconda3\envs\auto_post_instagram\Lib\site-packages\openai\resources\responses\responses.py:859, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     821 def create(
#     822     self,
#     823     *,
#    (...)    857     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     858 ) -> Response | Stream[ResponseStreamEvent]:
# --> 859     return self._post(
#     860         "/responses",
#     861         body=maybe_transform(
#     862             {
#     863                 "background": background,
#     864                 "conversation": conversation,
#     865                 "include": include,
#     866                 "input": input,
#     867                 "instructions": instructions,
#     868                 "max_output_tokens": max_output_tokens,
#     869                 "max_tool_calls": max_tool_calls,
#     870                 "metadata": metadata,
#     871                 "model": model,
#     872                 "parallel_tool_calls": parallel_tool_calls,
#     873                 "previous_response_id": previous_response_id,
#     874                 "prompt": prompt,
#     875                 "prompt_cache_key": prompt_cache_key,
#     876                 "prompt_cache_retention": prompt_cache_retention,
#     877                 "reasoning": reasoning,
#     878                 "safety_identifier": safety_identifier,
#     879                 "service_tier": service_tier,
#     880                 "store": store,
#     881                 "stream": stream,
#     882                 "stream_options": stream_options,
#     883                 "temperature": temperature,
#     884                 "text": text,
#     885                 "tool_choice": tool_choice,
#     886                 "tools": tools,
#     887                 "top_logprobs": top_logprobs,
#     888                 "top_p": top_p,
#     889                 "truncation": truncation,
#     890                 "user": user,
#     891             },
#     892             response_create_params.ResponseCreateParamsStreaming
#     893             if stream
#     894             else response_create_params.ResponseCreateParamsNonStreaming,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=Response,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ResponseStreamEvent],
#     902     )
#
# File c:\Users\AVRJ0006\anaconda3\envs\auto_post_instagram\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\AVRJ0006\anaconda3\envs\auto_post_instagram\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid value: 'text'. Supported values are: 'input_text', 'input_image', 'output_text', 'refusal', 'input_file', 'computer_screenshot', and 'summary_text'.", 'type': 'invalid_request_error', 'param': 'input[0].content[0].type', 'code': 'invalid_value'}}

# %%
# キャプション生成＆自動投稿実行
from main import auto_post_instagram
import json


# テンプレ読み込み
with open("./utils/template_example.json", encoding="utf-8") as f:
    templates_json = json.load(f)

user_input = {
    "business_type": "Private tour company",
    "title": "Welcome to the Stunning Autumn Colors of Shiga",
    "direction": "Please create content that highlights the beauty of Shiga’s autumn foliage and encourages visitors to come."
}


image_paths = ["./images/exam1.jpg", "./images/exam2.jpg", "./images/exam3.jpg"]

auto_post_instagram(user_input, image_paths, templates_json)
# Out:
# 投稿完了:Autumn has arrived in Shiga — a tapestry of crimson, gold, and amber that feels like stepping into a painting 🍁✨ Come see Lake Biwa and its surrounding hills glow in the season’s best light, and experience Japan’s autumn colors up close with a calm, private pace.
#
# Our tours cover the highlights of Shiga Prefecture, from lakeside panoramas around Lake Biwa to historic temple walks in the Koto Sanzan area. Spots like Ishiyamadera — famous for its autumn light-ups — Kongōrin-ji and Eigenji are especially stunning this time of year, each offering unforgettable views and peaceful paths to wander.
#
# Choose a private tour and enjoy a route made just for you: flexible timing to catch the perfect light, comfortable transport between viewpoints, and relaxed stops for photos, snacks, or a cozy lakeside cafe. We’ll tailor the day to your pace, whether you want to linger for golden-hour shots or explore multiple scenic spots without rushing.
#
# Perfect for nature lovers, photographers chasing that dreamy shot, families seeking a gentle day out, or couples after a romantic autumn escape. Our local guides handle the details — driving, parking, route timing, and local tips — so you can focus on soaking in the colors and moments.
#
# Ready to fall for Shiga this season? Send us a DM to plan your private autumn tour, and let’s create a day you’ll remember forever 🍂📷
#
# #Shiga #privatetour #japantravel #torutour #kansai #LakeBiwa #autumnleaves #fallcolors #travelJapan #photography

# %%
import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
CANVA_API_KEY = os.getenv("CANVA_API_KEY")
IG_ACCESS_TOKEN = os.getenv("IG_ACCESS_TOKEN")
IG_USER_ID = os.getenv("IG_USER_ID")

# %%
from utils.llm import run_gpt, run_gpt_json
from utils.caption_agent import run_caption_planner
import json


# ----------------------------------------
# 1. テンプレ読み込み
# ----------------------------------------
with open("./utils/template_example.json", encoding="utf-8") as f:
    templates_json = json.load(f)


# ----------------------------------------
# 2. ユーザー入力設定
# ----------------------------------------
user_input = {
    "business_type": "ラーメン店",
    "title": "新メニュー“焦がし醤油ラーメン”が完成！",
    "direction": "濃厚さと香りの魅力を伝えたい"
}


# ----------------------------------------
# 3. Caption Planner（テンプレ選択 & 質問生成）
# ----------------------------------------
plan = run_caption_planner(
    user_input=user_input,
    templates_json=templates_json,
)

print("▼ Caption Planner 出力")
print(json.dumps(plan, ensure_ascii=False, indent=2))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\AVRJ0006\YamatoDX\YAMATO_learning_practice\instagram_auto_post_system\project_git\instagram-auto-post-system\utils\llm.py:108, in run_gpt_json(prompt, history, model, max_completion_tokens, parse_json)
#     107 try:
# --> 108     return json.loads(content)
#     109 except json.JSONDecodeError as exc:
#
# File c:\Users\AVRJ0006\anaconda3\envs\auto_post_instagram\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
